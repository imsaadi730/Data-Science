# %%
from bs4 import BeautifulSoup
import requests

# %%
response = requests.get("https://www.express.pk/")

# %%
response.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n\n<head>\n\n    <meta charset="UTF-8">\n    <meta name="viewport" content="width=device-width,minimum-scale=1,initial-scale=1">\n    <meta http-equiv="X-UA-Compatible" content="ie=edge">\n    <meta name="fbAppId" property="fb:app_id" content="770767426360150" />\n    <meta name="fbPages" property="fb:pages" content="152904740527" />\n    <meta name="twitter:widgets:csp" content="on">\n    <meta name="theme-color" content="#000000" />\n    <meta name="mobile-web-app-capable" content="yes">\n    <meta name="msapplication-TileColor" content="#333333">\n    <meta name="apple-mobile-web-app-capable" content="yes">\n    <meta name="application-name" content="Express News">\n    <meta name="apple-mobile-web-app-title" content="Express News">\n    <meta name="apple-mobile-web-app-status-bar-style" content="black-translucent">\n    <meta name="msapplication-TileImage" content="https://img.express.pk/logo/144x144.png">\n    <link rel="apple-touch-icon" size
# ...

# %%
soup=BeautifulSoup(response.content,'html.parser')

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width,minimum-scale=1,initial-scale=1" name="viewport"/>
# <meta content="ie=edge" http-equiv="X-UA-Compatible"/>
# <meta content="770767426360150" name="fbAppId" property="fb:app_id">
# <meta content="152904740527" name="fbPages" property="fb:pages">
# <meta content="on" name="twitter:widgets:csp"/>
# <meta content="#000000" name="theme-color">
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="#333333" name="msapplication-TileColor"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="Express News" name="application-name"/>
# <meta content="Express News" name="apple-mobile-web-app-title"/>
# <meta content="black-translucent" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="https://img.express.pk/logo/144x144.png" name="msapplication-TileImage"/>
# ...

# %%
anchors=soup.find_all("a")

# %%
anchors[0]
# Out:
# <a href="https://tribune.com.pk/" rel="noopener" target="_blank">
#                                 EXPRESS TRIBUNE
#                             </a>

# %%
len(anchors)
# Out:
# 410

# %%
for anc in anchors:
    print("Title :",anc.text)
    print("Link :",anc["href"])
    print()
    print(">>>>>>>>>>>>>>>>>>>>>")
    print()
# Out:
# Title :
#                                 EXPRESS TRIBUNE
#
# Link : https://tribune.com.pk/
#
# >>>>>>>>>>>>>>>>>>>>>
#
# Title :
#                                 URDU E-PAPER
#
# Link : https://www.express.com.pk/
#
# >>>>>>>>>>>>>>>>>>>>>
#
# Title :
#                                 ENGLISH E-PAPER
#
# Link : https://tribune.com.pk/epaper
#
# >>>>>>>>>>>>>>>>>>>>>
#
# Title :
#                                 SINDHI E-PAPER
#
# Link : https://epaper.sindhexpress.com.pk/epaper/index.aspx
#
# >>>>>>>>>>>>>>>>>>>>>
#
# Title :
#                                 LIVE STREAMING
#
# Link : https://express.pk/live/
#
# >>>>>>>>>>>>>>>>>>>>>
#
# Title :
#                                 EXPRESS ENTERTAINMENT
#
# Link : https://www.expressentertainment.tv/
#
# >>>>>>>>>>>>>>>>>>>>>
#
# Title :
#                                 CRICKET PAKISTAN
#
# Link : https://cricketpakistan.com.pk/en
#
# >>>>>>>>>>>>>>>>>>>>>
#
# Title :
#                                 TODAY'S PAPER
#
# ...

# %%
#Search by Class name
top_reads=soup.find("section",attrs={"class":"new-most-read-widget"})
mr_arts=top_reads.find_all("div",attrs={"class":"related-post-sdBar"})

# %%
first=mr_arts[0]
print("image link :",first.find("img")["data-src"])
print("Titels :",first.find)
# Out:
# image link : https://img.express.pk/media/images/maulana-tariq-jameel-kashif-zameer1781717423-0/maulana-tariq-jameel-kashif-zameer1781717423-0-100x90.webp

# %%
link=[]
title=[]
images=[]
dops=[]

# %%
for first in mr_arts:
    link.append(first.find("img")["data-src"])
print(link)
# Out:
# ['https://img.express.pk/media/images/maulana-tariq-jameel-kashif-zameer1781717423-0/maulana-tariq-jameel-kashif-zameer1781717423-0-100x90.webp', 'https://img.express.pk/media/images/iranian-petroleum1779312596-0/iranian-petroleum1779312596-0-100x90.webp', 'https://img.express.pk/media/images/pm-shehbaz1781775908-0/pm-shehbaz1781775908-0-100x90.webp', 'https://img.express.pk/media/images/petrol-price1731486720-0/petrol-price1731486720-0-100x90.webp', 'https://img.express.pk/media/images/ory1781767322-2/ory1781767322-2-100x90.webp', 'https://img.express.pk/media/images/president-of-iran1781745813-0/president-of-iran1781745813-0-100x90.webp', 'https://img.express.pk/media/images/momina-iqbal-nasir-madni1781691905-0/momina-iqbal-nasir-madni1781691905-0-100x90.webp', 'https://img.express.pk/media/images/untitled-41781769821-0/untitled-41781769821-0-100x90.webp', 'https://img.express.pk/media/images/messi1781764412-0/messi1781764412-0-100x90.webp', 'https://img.express.pk/media/images/mau
# ...

# %%
import pandas as pd

# %%
df=pd.DataFrame({"links":link})

# %%
df.to_csv("D://link.csv")
