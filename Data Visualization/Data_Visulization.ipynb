# %% [markdown]
# ### ***Data Visualization***
# - Data science/Data Visualization/Happiness report/2019.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Happiness report/WHO_2019.csv")
Fifa=pd.read_csv("fifa_world_cup_2026_player_performance.csv")

# %%
df.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
Fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54600 entries, 0 to 54599
# Data columns (total 75 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   player_id                 54600 non-null  object
#  1   player_name               54600 non-null  object
#  2   age                       54600 non-null  int64
#  3   nationality               54600 non-null  object
#  4   team                      54600 non-null  object
#  5   jersey_number             54600 non-null  int64
#  6   position                  54600 non-null  object
#  7   height_cm                 54600 non-null  int64
#  8   weight_kg                 54600 non-null  int64
#  9   preferred_foot            54600 non-null  object
#  10  club_name                 54600 non-null  object
#  11  market_value_eur          54600 non-null  int64
#  12  match_id                  54600 non-null  object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
Fifa
# Out:
#       player_id       player_name  age nationality   team  jersey_number  \
# 0        P00055        Rodri Fati   26     Spanish  Spain              3
# 1        P00070   Ansu Le Normand   19     Spanish  Spain             18
# 2        P00066        Gavi Ramos   18     Spanish  Spain             14
# 3        P00073     Pedro Cubarsi   20     Spanish  Spain             21
# 4        P00059  Alvaro Oyarzabal   23     Spanish  Spain              7
# ...         ...               ...  ...         ...    ...            ...
# 54595    P00996       Amir Younis   28       Iraqi   Iraq              8
# 54596    P01006  Safaa Al-Khafaji   20       Iraqi   Iraq             18
# 54597    P01008     Ahmed Hussein   26       Iraqi   Iraq             20
# 54598    P00991     Ibrahim Mhawi   30       Iraqi   Iraq              3
# 54599    P00989  Mohannad Hussein   27       Iraqi   Iraq              1
#
#          position  height_cm  weight_kg preferred_foot  ... possession_impact  \
# ...

# %% [markdown]
# line
# scatter
# histo
# pie
# pair
# subplot
# hue plot
# barplot

# %%
# Basic Plot
plt.plot(df["Score"],df["Healthy life expectancy"])
plt.title("Healthy life expectancy")
plt.xlabel("Score")
plt.ylabel("Healthy life expectancy")
# Out:
# Text(0, 0.5, 'Healthy life expectancy')

# %%
sns.lineplot(x="Score",y="Healthy life expectancy", data=df)
# Out:
# <Axes: xlabel='Score', ylabel='Healthy life expectancy'>

# %%
sns.lineplot(x="age",y="goals",data=Fifa)
# Out:
# <Axes: xlabel='age', ylabel='goals'>

# %%
sns.scatterplot(x="age",y="goals",data=Fifa)
# Out:
# <Axes: xlabel='age', ylabel='goals'>

# %%
Fifa["goals"]=Fifa["goals"]*100

# %% [markdown]
# Histogram: when we want to data distribution in a single column(only for 1 column)

# %%
sns.histplot(x="goals",data=Fifa)
# Out:
# <Axes: xlabel='goals', ylabel='Count'>

# %%
fif5=Fifa[(Fifa["nationality"]=="Qatari") |(Fifa["nationality"]=="Jamaican") | (Fifa["nationality"]=="Moroccan")]

# %%
sns.barplot(x="nationality",y="goals",data=fif5)
# Out:
# <Axes: xlabel='nationality', ylabel='goals'>

# %%
fif5.columns
# Out:
# Index(['player_id', 'player_name', 'age', 'nationality', 'team',
#        'jersey_number', 'position', 'height_cm', 'weight_kg', 'preferred_foot',
#        'club_name', 'market_value_eur', 'match_id', 'match_date', 'stadium',
#        'city', 'opponent_team', 'tournament_stage', 'match_result',
#        'goals_team', 'goals_opponent', 'minutes_played', 'goals', 'assists',
#        'shots', 'shots_on_target', 'expected_goals_xg', 'expected_assists_xa',
#        'key_passes', 'successful_passes', 'total_passes', 'pass_accuracy',
#        'dribbles_attempted', 'successful_dribbles', 'crosses',
#        'successful_crosses', 'tackles', 'interceptions', 'clearances',
#        'blocks', 'aerial_duels_won', 'aerial_duels_lost', 'recoveries',
#        'defensive_actions', 'fouls_committed', 'fouls_suffered',
#        'yellow_cards', 'red_cards', 'offsides', 'saves', 'save_percentage',
#        'punches', 'clean_sheet', 'goals_conceded', 'penalty_saves',
# ...

# %%
sns.lineplot(x="age",y="market_value_eur",data=fif5)
# Out:
# <Axes: xlabel='age', ylabel='market_value_eur'>

# %%
df.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
(df["Country or region"]=="Pakistan") | (df["Country or region"]=="India") | (df["Country or region"]=="China") | (df["Country or region"]=="")]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df[""]
#
# ...

# %%
sns.boxplot(x="nationality",y="goals",data=fif5)
# Out:
# <Axes: xlabel='nationality', ylabel='goals'>

# %%
sns.barplot(x="nationality",y="goals",data=fif5)
# Out:
# <Axes: xlabel='nationality', ylabel='goals'>

# %%
sns.pairplot(df)

# %% [markdown]
# ## Subplots

# %%
plt.figure(figsze(15,10))

plt.subplots(2,3,1)
sns.lineplot(x="Healthy life exceptancy",y="Score",data=df)

plt.subplots(2,3,2)
sns.lineplot(x="Social suppot",y="Score",data=df)

plt.subplots(2,3,3)
sns.lineplot(x="Freedom to take life choices",y="Score",data=df)

plt.subplots(2,3,4)
sns.barplot(x="position",y="red_cards",data=fif5)

plt.subplots(2,3,5)
sns.barplot(x="position",y="age",data=fif5)

plt.subplots(2,3,6)
sns.barplot(x="position",y="performance_score",data=fif5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 plt.figure(figsze(15,10))
#       3 plt.subplots(2,3,1)
#       4 sns.lineplot(x="Healthy life exceptancy",y="Score",data=df)
#
# NameError: name 'figsze' is not defined

# %%
sns.pairplot(Fifa.sample(200))
plt.show
